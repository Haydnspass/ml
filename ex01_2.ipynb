# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os, os.path
from scipy import misc, ndimage
from skimage import filters
from PIL import Image
from itertools import chain
# %matplotlib inline

# %%
# import data - part (a)

class Picture:
    def __init__(self, rgbFilepath, groundFilepath):
        self.rgbFilepath = rgbFilepath
        self.groundFilepath = groundFilepath
        rgbImage= ndimage.imread(rgbFilepath)
        groundImage = ndimage.imread(groundFilepath)
        
        # downscale
        resizedSize = min(rgbImage.shape,groundImage.shape);
        self.rgbImage = misc.imresize(rgbImage, resizedSize)        
        self.groundImage = misc.imresize(groundImage, resizedSize[0:2])
        

def readFromDirectory(directory):
    files = []
    validExtensions = ['.jpeg', '.jpg']
    for currentFile in os.listdir(os.path.join(directory, 'rgb')):
        if not os.path.splitext(currentFile)[1] in validExtensions:
            print('skipped')
            continue
        files.append(Picture(
            os.path.join(directory, 'rgb', currentFile),
            os.path.join(directory, 'figure_ground', currentFile)
        ))
    return files

allPictures = readFromDirectory('pictureData')
# select first few for training
trainPictures = allPictures[0:10]
# select other 10 for testing purpose
testPictures = [allPictures[i] for i in [13,14,15,17,19,20,21,22,26,27]]

# %%
# compute features - part (b)

# first resize images
for i in range(0,len(imgTrainingData)):
    # downscale
    resizedSize = min(imgTrainingData[i].shape,imgTestingData[i].shape);
    
    imgTrainingDataGaussian.append(filters.gaussian(imgTrainingData[i], sigma = 1, multichannel = True))
    imgTrainingDataLaplace.append(filters.laplace(imgTrainingData[i]))
    imgTrainingDataMedian.append(filters.median(imgTrainingData[i]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-135-179701c5f06e> in <module>()
#      10     imgTrainingDataGaussian.append(filters.gaussian(imgTrainingData[i], sigma = 1, multichannel = True))
#      11     imgTrainingDataLaplace.append(filters.laplace(imgTrainingData[i]))
# ---> 12     imgTrainingDataMedian.append(filters.median(imgTrainingData[i]))
#
# TypeError: median() missing 1 required positional argument: 'selem'

# %%
imgplot = plt.imshow(trainPictures[0])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-118-401926316f8c> in <module>()
# ----> 1 imgplot = plt.imshow(trainPictures[0])
#       2 plt.show()
#
# NameError: name 'trainPictures' is not defined

# %%
imgplot2 = plt.imshow(imgTrainingDataLaplace[0])
plt.show()

# %%
imgTrainingDataGaussian[i] = gaussian(imgTrainingData[i])

# %%
type(imgTrainingData)
# Out:
# list

# %%
y
# Out:
# (212, 269)

# %%
t = min(x[:],y[:])

# %%
t
# Out:
# (197, 250, 3)

# %%
t[0:2]
# Out:
# (197, 250)

# %%
for k in chain([123, 456, 2],[3,2,1]):
    print(k)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-117-068bf7805386> in <module>()
# ----> 1 for k in chain([123, 456, 2],[3,2,1]):
#       2     print(k)
#
# NameError: name 'chain' is not defined
